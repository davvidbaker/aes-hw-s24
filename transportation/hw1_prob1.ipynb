# %%
import pandas as pd

# %%
df1 = pd.read_excel('AEO_LDVSales_2022.xlsx')

battery_electric_ldv_sales = df1["battery electric"] * 1e6

df1
# Out:
#     Unnamed: 0   gasoline  flex fuel    diesel  battery electric      PHEV  \
# 0         2010   9.069512   1.311502  0.026521          0.000567  0.000000
# 1         2011  11.151818   2.009542  0.045833          0.010573  0.008365
# 2         2012  11.587757   2.383854  0.115724          0.010935  0.056682
# 3         2013  13.155411   2.560983  0.133822          0.052945  0.054687
# 4         2014  13.591879   2.291614  0.188306          0.045915  0.061426
# 5         2015  14.932074   1.714477  0.154692          0.077050  0.045621
# 6         2016  14.356198   1.094807  0.075089          0.078129  0.047319
# 7         2017  15.390056   1.226671  0.047423          0.096463  0.129503
# 8         2018  15.061461   0.839878  0.065037          0.177661  0.133673
# 9         2019  15.278036   0.994937  0.021578          0.181402  0.084129
# 10        2020  11.057555   0.608366  0.060647          0.240442  0.058055
# ...

# %%
df2 = pd.read_excel('AEO_TransportModeEnergy_2022.xlsx')

df2
# Out:
#     Unnamed: 0     other    marine      rail  commercial light trucks  \
# 0         2010  1.744085  1.289765  0.470602                 0.719955
# 1         2011  1.735027  1.170792  0.537824                 0.746866
# 2         2012  1.664829  1.029447  0.500460                 0.754027
# 3         2013  1.545234  0.985096  0.512351                 0.788067
# 4         2014  1.627396  0.895547  0.543349                 0.810485
# 5         2015  1.649167  0.957168  0.524324                 0.836901
# 6         2016  1.603133  1.138780  0.464556                 0.855010
# 7         2017  1.556345  1.172998  0.496259                 0.860240
# 8         2018  1.678310  1.121576  0.533136                 0.893540
# 9         2019  1.709260  1.069680  0.509795                 0.891442
# 10        2020  1.632812  1.114745  0.466677                 0.834650
# 11        2021  1.586352  1.206718  0.503996                 0.888323
# ...

# %%
df3 = pd.read_excel('TEDB40_LDVs_2022.xlsx')
df3
# Out:
#     Year  Vehicles Registerted  Billion Miles traveled   \
# 0   1970                103455                     1040
# 1   1975                127124                     1235
# 2   1980                149477                     1403
# 3   1985                165099                     1638
# 4   1986                169386                     1694
# 5   1987                172589                     1773
# 6   1988                177641                     1872
# 7   1989                180504                     1938
# 8   1990                181975                     1983
# 9   1991                181333                     2008
# 10  1992                183672                     2078
# 11  1993                187321                     2120
# 12  1994                190787                     2171
# 13  1995                194125                     2228
# 14  1996                198862                     2286
# 15  1997                199973                     2353
# ...
