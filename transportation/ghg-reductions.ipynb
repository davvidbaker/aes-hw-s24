# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# GGE_{total} = \sum\limits_{mode}{GGE_{mode}} = \sum\limits_{mode}(\dfrac{GGE}{E})(\dfrac{E}{PKT})
# (PKT)
# $

# %% [markdown]
# $
# PKT = (2\times distance_{one-way}) (250 \mathrm{\tfrac{trips}{year}}) (number\ of\ commuters)
# $

# %% [markdown]
# $
# \dfrac{E}{PKT} = \mathrm{\tfrac{gallon_{diesel}}{5.3\ miles} \cdot 138000\tfrac{BTU}{gallon_{diesel}} \cdot \tfrac{vehicle}{10.7 \ passengers} \cdot \tfrac{mile}{1.6\ km} \cdot \tfrac {0.000293071\ kWh}{BTU} = 0.448\ \tfrac{kWh}{PKT}}
# $
